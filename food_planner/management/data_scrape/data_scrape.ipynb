# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

URL = "https://www.simplyrecipes.com/recipes-5090746"


def get_data(url: str):
    """Collects the recipes"""

    header = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36"
    }
    r = requests.get(url, headers=header)
    soup = bs(r.content, "html.parser")
    section = soup.find("section")

    data = section.find("div", class_="loc fixedContent")

    return data


def get_recipes(data: str) -> list:
    """Scrapes the foods"""

    recipes = data.findAll("span", class_="card__title-text")
    recipes = [r.get_text() for r in recipes]

    return recipes


def get_urls(data: str) -> list:
    """Scrapes the urls"""

    urls = [d["href"] for d in data.find_all("a", href=True)]
    urls = [u for u in urls if u != "#"]

    return urls

def get_images(data: str):
    
    images = [d["src"] for d in data.find_all("img", src=True)]

    return images

def get_csv(recipes: list, urls: list):
    """Save the scraped data in csv"""

    df = pd.DataFrame({"recipes": recipes, "urls": urls})

    df.to_csv("../project/recipe.csv")

# %%
data = get_data(URL)

# %%
data
# Out:
# <div class="loc fixedContent">
# <div class="comp mntl-document-spotlight taxonomysc-spotlight mntl-sc-block-spotlight mntl-block" data-tracking-container="true" id="mntl-document-spotlight_1-0">
# <div class="comp mntl-sc-block-spotlight__articles mntl-document-spotlight mntl-document-card-list mntl-card-list mntl-block" data-chunk="36" id="mntl-sc-block-spotlight__articles_1-0">
# <a class="comp mntl-card-list-items mntl-document-card mntl-card card" data-cta="Read Now ▸" data-doc-id="7110027" data-ordinal="1" data-tax-levels="" href="https://www.simplyrecipes.com/vegan-meatballs-recipe-7110027" id="mntl-card-list-items_1-0">
# <div class="card__media" data-tag="Dinners">
# <div class="img-placeholder" style="padding-bottom:66.6%;">
# <img alt="Vegan Meatballs in a Cast Iron Skillet with Tomato Sauce " class="lazyload card__img" data-dim-ratio="1.499" data-src="https://www.simplyrecipes.com/thmb/a19vX-drZNx6JPiLxinkknRWQEw=/450x300/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Vegan-MeatballsLEAD-12-55c5f73e734d47ea8233e6370031b517.jpg" height="300" width="450"/>
# <noscript>
# <img alt="Vegan Meatballs in a Cast Iron Skillet with Tomato Sauce " class="img--noscript card__img" height="300" src="https://www.simplyrecipes.com/thmb/a19vX-drZNx6JPiLxinkknRWQEw=/450x300/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Vegan-MeatballsLEAD-12-55c5f73e734d47ea8233e6370031b517.jpg" width="450"/>
# </noscript>
# </div> </div>
# <div class="card__content" data-tag="Dinners">
# <div class="card__header"></div>
# <span class="card__title"><span class="card__title-text">Vegan Meatballs</span></span>
# <div class="card__byline mntl-card__byline" data-byline="Julie &amp; Amy Luxemberg"></div>
# </div>
# <div class="loc card__footer">
# <span class="comp meta-text--recipe meta-text" id="meta-text--recipe_3-0">
# <svg class="meta-text__icon">
# <use xlink:href="#icon-clock" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="meta-text__text">
# 31 mins
# </span>
# </span>
# </div>
# </a>
# <a class="comp mntl-card-list-items mntl-document-card mntl-card card" data-cta="Read Now ▸" data-doc-id="7108940" data-ordinal="2" data-tax-levels="" href="https://www.simplyrecipes.com/pesto-chicken-meatballs-recipe-7108940" id="mntl-card-list-items_1-0-1">
# <div class="card__media" data-tag="Dinners">
# <div class="img-placeholder" style="padding-bottom:66.6%;">
# <img alt="Plate of Pesto Meatballs with Two Bowls of Sauce (Pesto and Marinara)" class="lazyload card__img" data-dim-ratio="1.5" data-src="https://www.simplyrecipes.com/thmb/gROm3HVLmQJ4fFwY66msrfK4-f4=/450x300/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Pesto-Chicken-Meatballs-LEAD-26-e8bcc6962b3d42549ab05750c44f0ab0.jpg" height="300" width="450"/>
# <noscript>
# <img alt="Plate of Pesto Meatballs with Two Bowls of Sauce (Pesto and Marinara)" class="img--noscript card__img" height="300" src="https://www.simplyrecipes.com/thmb/gROm3HVLmQJ4fFwY66msrfK4-f4=/450x300/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Pesto-Chicken-Meatballs-LEAD-26-e8bcc6962b3d42549ab05750c44f0ab0.jpg" width="450"/>
# </noscript>
# </div> </div>
# <div class="card__content" data-tag="Dinners">
# <div class="card__header"></div>
# <span class="card__title"><span class="card__title-text">Pesto Chicken Meatballs</span></span>
# <div class="card__byline mntl-card__byline" data-byline="Sheela Prakash"></div>
# </div>
# <div class="loc card__footer">
# <span class="comp meta-text--recipe meta-text" id="meta-text--recipe_3-0-1">
# <svg class="meta-text__icon">
# <use xlink:href="#icon-clock" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="meta-text__text">
# 33 mins
# </span>
# </span>
# </div>
# </a>
# <a class="comp mntl-card-list-items mntl-document-card mntl-card card" data-cta="Read Now ▸" data-doc-id="7110223" data-ordinal="3" data-tax-levels="" href="https://www.simplyrecipes.com/how-to-temper-chocolate-easiest-method-7110223" id="mntl-card-list-items_1-0-2">
# <div class="card__media" data-tag="Cooking Tips &amp; Techniques">
# <div class="img-placeholder" style="padding-bottom:66.6%;">
# <img alt="Overhead view of a glass bowl of melted chocolate." class="lazyload card__img" data-dim-ratio="1.5" data-src="https://www.simplyrecipes.com/thmb/qXJqlfPTTLQENR5_oOOPB62oSJc=/450x300/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Extra-Rich-Chocolate-Frosting-METHOD-3-version-2-64e1448e7b744cb4a732732b6ba8ecbf.jpg" height="300" width="450"/>
# <noscript>
# <img alt="Overhead view of a glass bowl of melted chocolate." class="img--noscript card__img" height="300" src="https://www.simplyrecipes.com/thmb/qXJqlfPTTLQENR5_oOOPB62oSJc=/450x300/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Extra-Rich-Chocolate-Frosting-METHOD-3-version-2-64e1448e7b744cb4a732732b6ba8ecbf.jpg" width="450"/>
# </noscript>
# </div> </div>
# <div class="card__content" data-tag="Cooking Tips &amp; Techniques">
# <div class="card__header"></div>
# <span class="card__title"><span class="card__title-text">How to Temper Chocolate</span></span>
# <div class="card__byline mntl-card__byline" data-byline="Sara Bir"></div>
# </div>
# <div class="loc card__footer">
# <span class="comp meta-text--recipe meta-text" id="meta-text--recipe_3-0-2">
# <svg class="meta-text__icon">
# <use xlink:href="#icon-clock" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="meta-text__text">
# 13 mins
# </span>
# </span>
# </div>
# </a>
# </div>
# </div>
# <div class="comp l-container mntl-taxonomysc-child-nodes mntl-block" id="mntl-taxonomysc-child-nodes_1-0">
# <h3 class="comp mntl-taxonomysc-child-nodes__heading mntl-text-block" id="mntl-taxonomysc-child-nodes__heading_1-0">
# Explore Recipes</h3>
# <div class="comp has-dropdown mntl-taxonomysc-child-nodes__wrapper mntl-block" id="mntl-taxonomysc-child-nodes__wrapper_1-0">
# <a class="mntl-taxonomysc-child-node__view-all mntl-text-link mntl-taxonomysc-child-node is-active is-loaded" data-docid="5090746" data-tracking-container="true" href="#" id="mntl-taxonomysc-child-node__view-all_1-0" rel="nocaes"><span class="link__wrapper">All</span></a>
# <a class="mntl-taxonomysc-child-links__list mntl-text-link mntl-taxonomysc-child-node" data-docid="5091433" data-tracking-container="true" href="#" id="mntl-taxonomysc-child-links__list_2-0" rel="nocaes"><span class="link__wrapper">Dinners</span></a>
# <a class="mntl-taxonomysc-child-links__list mntl-text-link mntl-taxonomysc-child-node" data-docid="5091263" data-tracking-container="true" href="#" id="mntl-taxonomysc-child-links__list_2-0-1" rel="nocaes"><span class="link__wrapper">Lunches</span></a>
# <a class="mntl-taxonomysc-child-links__list mntl-text-link mntl-taxonomysc-child-node" data-docid="5091541" data-tracking-container="true" href="#" id="mntl-taxonomysc-child-links__list_2-0-2" rel="nocaes"><span class="link__wrapper">Breakfast</span></a>
# <a class="mntl-taxonomysc-child-links__list mntl-text-link mntl-taxonomysc-child-node" data-docid="5091513" data-tracking-container="true" href="#" id="mntl-taxonomysc-child-links__list_2-0-3" rel="nocaes"><span class="link__wrapper">Desserts</span></a>
# <div class="comp mntl-taxonomysc-child-node__dropdown-wrapper mntl-block" id="mntl-taxonomysc-child-node__dropdown-wrapper_1-0">
# <button class="comp mntl-taxonomysc-child-node__more-button mntl-button" data-event-trigger="click" data-tracking-container="true" id="mntl-taxonomysc-child-node__more-button_1-0">
# <svg class="icon arrow-circle mntl-button__icon mntl-taxnomony-sc-child-node__more-button-icon">
# <use xlink:href="#arrow-circle" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </button>
# <div class="comp mntl-taxonomysc-child-node__dropdown mntl-block" id="mntl-taxonomysc-child-node__dropdown_1-0">
# <a class="mntl-taxonomysc-child-links__list mntl-text-link mntl-taxonomysc-child-node mntl-taxonomysc-child-node__list-item" data-docid="5090762" data-tracking-container="true" href="#" id="mntl-taxonomysc-child-links__list_3-0" rel="nocaes"><span class="link__wrapper">Snacks and Appetizers</span></a>
# <a class="mntl-taxonomysc-child-links__list mntl-text-link mntl-taxonomysc-child-node mntl-taxonomysc-child-node__list-item" data-docid="5091323" data-tracking-container="true" href="#" id="mntl-taxonomysc-child-links__list_3-0-1" rel="nocaes"><span class="link__wrapper">Drinks</span></a>
# <a class="mntl-taxonomysc-child-links__list mntl-text-link mntl-taxonomysc-child-node mntl-taxonomysc-child-node__list-item" data-docid="5091321" data-tracking-container="true" href="#" id="mntl-taxonomysc-child-links__list_3-0-2" rel="nocaes"><span class="link__wrapper">Holidays and Seasons</span></a>
# <a class="mntl-taxonomysc-child-links__list mntl-text-link mntl-taxonomysc-child-node mntl-taxonomysc-child-node__list-item" data-docid="5091192" data-tracking-container="true" href="#" id="mntl-taxonomysc-child-links__list_3-0-3" rel="nocaes"><span class="link__wrapper">Recipes By Ingredients</span></a>
# <a class="mntl-taxonomysc-child-links__list mntl-text-link mntl-taxonomysc-child-node mntl-taxonomysc-child-node__list-item" data-docid="5091235" data-tracking-container="true" href="#" id="mntl-taxonomysc-child-links__list_3-0-4" rel="nocaes"><span class="link__wrapper">Recipes By Method</span></a>
# <a class="mntl-taxonomysc-child-links__list mntl-text-link mntl-taxonomysc-child-node mntl-taxonomysc-child-node__list-item" data-docid="5091259" data-tracking-container="true" href="#" id="mntl-taxonomysc-child-links__list_3-0-5" rel="nocaes"><span class="link__wrapper">Recipes By Diet</span></a>
# <a class="mntl-taxonomysc-child-links__list mntl-text-link mntl-taxonomysc-child-node mntl-taxonomysc-child-node__list-item" data-docid="5090817" data-tracking-container="true" href="#" id="mntl-taxonomysc-child-links__list_3-0-6" rel="nocaes"><span class="link__wrapper">Recipes By Time and Ease</span></a>
# <a class="mntl-taxonomysc-child-links__list mntl-text-link mntl-taxonomysc-child-node mntl-taxonomysc-child-node__list-item" data-docid="5090811" data-tracking-container="true" href="#" id="mntl-taxonomysc-child-links__list_3-0-7" rel="nocaes"><span class="link__wrapper">Recipes By World Cuisine</span></a>
# <a class="mntl-taxonomysc-child-links__list mntl-text-link mntl-taxonomysc-child-node mntl-taxonomysc-child-node__list-item" data-docid="5121175" data-tracking-container="true" href="#" id="mntl-taxonomysc-child-links__list_3-0-8" rel="nocaes"><span class="link__wrapper">Most Recent</span></a>
# </div>
# </div>
# </div>
# </div>
# <div class="comp l-container mntl-taxonomysc-article-list-group mntl-block" data-scroll-offset="80" id="mntl-taxonomysc-article-list-group_1-0">
# <div class="comp mntl-taxonomysc-article-list mntl-document-card-list mntl-card-list mntl-block" data-chunk="36" data-docid="5090746" id="mntl-taxonomysc-article-list_1-0">
# <a class="comp mntl-card-list-items mntl-document-card mntl-card card" data-cta="" data-doc-id="7089865" data-ordinal="1" data-tax-levels="" href="https://www.simplyrecipes.com/lok-lak-shaking-beef-recipe-7089865" id="mntl-card-list-items_2-0">
# <div class="card__media" data-tag="Dinners">
# <div class="img-placeholder" style="padding-bottom:75.0%;">
# <img alt="Platter of Lok Lak Served Over Sliced Tomatoes and Lettuce at a Table Setting With a Bowl of Rice, a Plate With a Serving of Lok Lak, and a Bowl of Pepper-lime Sauce " class="lazyload card__img" data-dim-ratio="1.5" data-src="https://www.simplyrecipes.com/thmb/rAYr46dtn76ppnnfpbCgKaAZzJc=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Lok-Lak-Mustard-LEAD-06-4b5fba1a87b64b4cad472b261375c272.jpg" height="225" width="300"/>
# <noscript>
# <img alt="Platter of Lok Lak Served Over Sliced Tomatoes and Lettuce at a Table Setting With a Bowl of Rice, a Plate With a Serving of Lok Lak, and a Bowl of Pepper-lime Sauce " class="img--noscript card__img" height="225" src="https://www.simplyrecipes.com/thmb/rAYr46dtn76ppnnfpbCgKaAZzJc=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Lok-Lak-Mustard-LEAD-06-4b5fba1a87b64b4cad472b261375c272.jpg" width="300"/>
# </noscript>
# </div> </div>
# <div class="card__content" data-tag="Dinners">
# <div class="card__header"></div>
# <span class="card__title"><span class="card__title-text">Lok Lak (Shaking Beef)</span></span>
# </div>
# <div class="loc card__footer">
# <span class="comp meta-text--recipe meta-text" id="meta-text--recipe_4-0">
# <svg class="meta-text__icon">
# <use xlink:href="#icon-clock" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="meta-text__text">
# 25 mins
# </span>
# </span>
# <div class="comp aggregate-star-rating aggregate-star-rating--card" id="aggregate-star-rating--card_3-0">
# <span class="aggregate-star-rating__title">Ratings</span>
# <div class="comp mntl-aggregate-star-rating mntl-rating" data-doc-id="0" id="mntl-aggregate-star-rating_4-0">
# <span aria-label="Rate 1-star" class="active" data-ordinal="1" data-rating="1">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 2-star" class="active" data-ordinal="2" data-rating="2">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 3-star" class="active" data-ordinal="3" data-rating="3">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 4-star" class="active" data-ordinal="4" data-rating="4">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 5-star" class="active" data-ordinal="5" data-rating="5">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span></div>
# </div>
# </div>
# </a>
# <a class="comp mntl-card-list-items mntl-document-card mntl-card card" data-cta="" data-doc-id="7099389" data-ordinal="2" data-tax-levels="" href="https://www.simplyrecipes.com/oatmeal-banana-cookies-recipe-7099389" id="mntl-card-list-items_2-0-1">
# <div class="card__media" data-tag="Cookies">
# <div class="img-placeholder" style="padding-bottom:75.0%;">
# <img alt="Stack of Oatmeal Banana Cookies Next to a Glass of Milk, and in the Background, More Cookies on the Counter" class="lazyload card__img" data-dim-ratio="1.499" data-src="https://www.simplyrecipes.com/thmb/gmH-83ogsJRUB2svE9bFnjE-P5Y=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Oatmeal-Banana-Cookies-LEAD-05-a0047f8e7c2a484c8529ba49db9f90d9.jpg" height="225" width="300"/>
# <noscript>
# <img alt="Stack of Oatmeal Banana Cookies Next to a Glass of Milk, and in the Background, More Cookies on the Counter" class="img--noscript card__img" height="225" src="https://www.simplyrecipes.com/thmb/gmH-83ogsJRUB2svE9bFnjE-P5Y=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Oatmeal-Banana-Cookies-LEAD-05-a0047f8e7c2a484c8529ba49db9f90d9.jpg" width="300"/>
# </noscript>
# </div> </div>
# <div class="card__content" data-tag="Cookies">
# <div class="card__header"></div>
# <span class="card__title"><span class="card__title-text">Oatmeal Banana Cookies </span></span>
# </div>
# <div class="loc card__footer">
# <span class="comp meta-text--recipe meta-text" id="meta-text--recipe_4-0-1">
# <svg class="meta-text__icon">
# <use xlink:href="#icon-clock" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="meta-text__text">
# 22 mins
# </span>
# </span>
# <div class="comp aggregate-star-rating aggregate-star-rating--card" id="aggregate-star-rating--card_3-0-1">
# <span class="aggregate-star-rating__title">Ratings</span>
# <div class="comp mntl-aggregate-star-rating mntl-rating" data-doc-id="0" id="mntl-aggregate-star-rating_4-0-1">
# <span aria-label="Rate 1-star" class="active" data-ordinal="1" data-rating="1">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 2-star" class="active" data-ordinal="2" data-rating="2">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 3-star" class="active" data-ordinal="3" data-rating="3">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 4-star" class="active" data-ordinal="4" data-rating="4">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 5-star" class="active" data-ordinal="5" data-rating="5">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span></div>
# </div>
# </div>
# </a>
# <a class="comp mntl-card-list-items mntl-document-card mntl-card card" data-cta="" data-doc-id="7097608" data-ordinal="3" data-tax-levels="" href="https://www.simplyrecipes.com/adobo-chicken-meatballs-recipe-7097608" id="mntl-card-list-items_2-0-2">
# <div class="card__media" data-tag="Dinners">
# <div class="img-placeholder" style="padding-bottom:75.0%;">
# <img alt="Adobo Chicken Meatballs in a Bowl Next to a Table Napkin, a Serving Spoon, and a Bowl of Rice" class="lazyload card__img" data-dim-ratio="1.5" data-src="https://www.simplyrecipes.com/thmb/Y9-Ly4hosuxHiYyA9PlTrWy4oVw=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Chicken-Adobo-Meatballs-LEAD-05-543f271321c142fe84a3acb17ab5dd3c.jpg" height="225" width="300"/>
# <noscript>
# <img alt="Adobo Chicken Meatballs in a Bowl Next to a Table Napkin, a Serving Spoon, and a Bowl of Rice" class="img--noscript card__img" height="225" src="https://www.simplyrecipes.com/thmb/Y9-Ly4hosuxHiYyA9PlTrWy4oVw=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Chicken-Adobo-Meatballs-LEAD-05-543f271321c142fe84a3acb17ab5dd3c.jpg" width="300"/>
# </noscript>
# </div> </div>
# <div class="card__content" data-tag="Dinners">
# <div class="card__header"></div>
# <span class="card__title"><span class="card__title-text">Adobo Chicken Meatballs</span></span>
# </div>
# <div class="loc card__footer">
# <span class="comp meta-text--recipe meta-text" id="meta-text--recipe_4-0-2">
# <svg class="meta-text__icon">
# <use xlink:href="#icon-clock" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="meta-text__text">
# 40 mins
# </span>
# </span>
# <div class="comp aggregate-star-rating aggregate-star-rating--card" id="aggregate-star-rating--card_3-0-2">
# <span class="aggregate-star-rating__title">Ratings</span>
# <div class="comp mntl-aggregate-star-rating mntl-rating" data-doc-id="0" id="mntl-aggregate-star-rating_4-0-2">
# <span aria-label="Rate 1-star" class="active" data-ordinal="1" data-rating="1">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 2-star" class="active" data-ordinal="2" data-rating="2">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 3-star" class="active" data-ordinal="3" data-rating="3">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 4-star" class="active" data-ordinal="4" data-rating="4">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 5-star" class="active" data-ordinal="5" data-rating="5">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span></div>
# </div>
# </div>
# </a>
# <a class="comp mntl-card-list-items mntl-document-card mntl-card card" data-cta="" data-doc-id="7099960" data-ordinal="4" data-tax-levels="" href="https://www.simplyrecipes.com/egg-masala-curry-recipe-7099960" id="mntl-card-list-items_2-0-3">
# <div class="card__media" data-tag="Dinners">
# <div class="img-placeholder" style="padding-bottom:75.0%;">
# <img alt="Plate of Egg Masala Curry with a Spoon on a Kitchen Linen" class="lazyload card__img" data-dim-ratio="1.5" data-src="https://www.simplyrecipes.com/thmb/mrE41FdSB8SYfPsimDM_Ste0DjU=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simple-Recipes-Egg-Masala-Curry-Lead-06-1225dad91b8b4531bdc0195fea8fa774.jpg" height="225" width="300"/>
# <noscript>
# <img alt="Plate of Egg Masala Curry with a Spoon on a Kitchen Linen" class="img--noscript card__img" height="225" src="https://www.simplyrecipes.com/thmb/mrE41FdSB8SYfPsimDM_Ste0DjU=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simple-Recipes-Egg-Masala-Curry-Lead-06-1225dad91b8b4531bdc0195fea8fa774.jpg" width="300"/>
# </noscript>
# </div> </div>
# <div class="card__content" data-tag="Dinners">
# <div class="card__header"></div>
# <span class="card__title"><span class="card__title-text">Egg Masala Curry</span></span>
# </div>
# <div class="loc card__footer">
# <span class="comp meta-text--recipe meta-text" id="meta-text--recipe_4-0-3">
# <svg class="meta-text__icon">
# <use xlink:href="#icon-clock" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="meta-text__text">
# 35 mins
# </span>
# </span>
# </div>
# </a>
# <a class="comp mntl-card-list-items mntl-document-card mntl-card card" data-cta="" data-doc-id="7097630" data-ordinal="5" data-tax-levels="" href="https://www.simplyrecipes.com/lion-s-head-meatballs-recipe-7097630" id="mntl-card-list-items_2-0-4">
# <div class="card__media" data-tag="Dinners">
# <div class="img-placeholder" style="padding-bottom:75.0%;">
# <img alt="Lion's Head Meatballs Served on a Bed of Cabbage on a Platter" class="lazyload card__img" data-dim-ratio="1.5" data-src="https://www.simplyrecipes.com/thmb/V1LnCxr2hVRoHBT_OEinBoeqix0=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Lions-Head-Meatball-LEAD-02-a4f2a9955428409097f0155e98df2b9c.jpg" height="225" width="300"/>
# <noscript>
# <img alt="Lion's Head Meatballs Served on a Bed of Cabbage on a Platter" class="img--noscript card__img" height="225" src="https://www.simplyrecipes.com/thmb/V1LnCxr2hVRoHBT_OEinBoeqix0=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Lions-Head-Meatball-LEAD-02-a4f2a9955428409097f0155e98df2b9c.jpg" width="300"/>
# </noscript>
# </div> </div>
# <div class="card__content" data-tag="Dinners">
# <div class="card__header"></div>
# <span class="card__title"><span class="card__title-text">Lion’s Head Meatballs</span></span>
# </div>
# <div class="loc card__footer">
# <span class="comp meta-text--recipe meta-text" id="meta-text--recipe_4-0-4">
# <svg class="meta-text__icon">
# <use xlink:href="#icon-clock" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="meta-text__text">
# 35 mins
# </span>
# </span>
# </div>
# </a>
# <a class="comp mntl-card-list-items mntl-document-card mntl-card card" data-cta="" data-doc-id="7097530" data-ordinal="6" data-tax-levels="" href="https://www.simplyrecipes.com/beef-enchilada-casserole-recipe-7097530" id="mntl-card-list-items_2-0-5">
# <div class="card__media" data-tag="Dinners">
# <div class="img-placeholder" style="padding-bottom:75.0%;">
# <img alt="Beef Enchilada Casserole in a Casserole Dish Next to a Table Cloth, a Plate, and a Bowl with Side Salad " class="lazyload card__img" data-dim-ratio="1.5" data-src="https://www.simplyrecipes.com/thmb/hgwK3f1aGmG27r9qHEjNnQ1cqMQ=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Beef-Enchilada-Casserole-LEAD-02-ad4ba62363a44a85b8f281a806697f44.jpg" height="225" width="300"/>
# <noscript>
# <img alt="Beef Enchilada Casserole in a Casserole Dish Next to a Table Cloth, a Plate, and a Bowl with Side Salad " class="img--noscript card__img" height="225" src="https://www.simplyrecipes.com/thmb/hgwK3f1aGmG27r9qHEjNnQ1cqMQ=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Beef-Enchilada-Casserole-LEAD-02-ad4ba62363a44a85b8f281a806697f44.jpg" width="300"/>
# </noscript>
# </div> </div>
# <div class="card__content" data-tag="Dinners">
# <div class="card__header"></div>
# <span class="card__title"><span class="card__title-text">Beef Enchilada Casserole </span></span>
# </div>
# <div class="loc card__footer">
# <span class="comp meta-text--recipe meta-text" id="meta-text--recipe_4-0-5">
# <svg class="meta-text__icon">
# <use xlink:href="#icon-clock" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="meta-text__text">
# 65 mins
# </span>
# </span>
# <div class="comp aggregate-star-rating aggregate-star-rating--card" id="aggregate-star-rating--card_3-0-3">
# <span class="aggregate-star-rating__title">Ratings</span>
# <div class="comp mntl-aggregate-star-rating mntl-rating" data-doc-id="0" id="mntl-aggregate-star-rating_4-0-3">
# <span aria-label="Rate 1-star" class="active" data-ordinal="1" data-rating="1">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 2-star" class="active" data-ordinal="2" data-rating="2">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 3-star" class="active" data-ordinal="3" data-rating="3">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 4-star" class="active" data-ordinal="4" data-rating="4">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 5-star" class="active" data-ordinal="5" data-rating="5">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span></div>
# </div>
# </div>
# </a>
# <a class="comp mntl-card-list-items mntl-document-card mntl-card card" data-cta="" data-doc-id="7100340" data-ordinal="7" data-tax-levels="" href="https://www.simplyrecipes.com/oyster-po-boy-recipe-7100340" id="mntl-card-list-items_2-0-6">
# <div class="card__media" data-tag="Dinners">
# <div class="img-placeholder" style="padding-bottom:75.0%;">
# <img alt="A Platter Filled with Oyster Po' Boys, Surrounded by a Kitchen Towel and a Bowl of Remoulade " class="lazyload card__img" data-dim-ratio="1.5" data-src="https://www.simplyrecipes.com/thmb/iszZyoeNmaAXysLMUeams9RPGGc=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Oyster-PoBoy-LEAD-03-919049a1cacb4b78881ced4ea2eac4a7.jpg" height="225" width="300"/>
# <noscript>
# <img alt="A Platter Filled with Oyster Po' Boys, Surrounded by a Kitchen Towel and a Bowl of Remoulade " class="img--noscript card__img" height="225" src="https://www.simplyrecipes.com/thmb/iszZyoeNmaAXysLMUeams9RPGGc=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Oyster-PoBoy-LEAD-03-919049a1cacb4b78881ced4ea2eac4a7.jpg" width="300"/>
# </noscript>
# </div> </div>
# <div class="card__content" data-tag="Dinners">
# <div class="card__header"></div>
# <span class="card__title"><span class="card__title-text">Oyster Po’ Boy</span></span>
# </div>
# <div class="loc card__footer">
# <span class="comp meta-text--recipe meta-text" id="meta-text--recipe_4-0-6">
# <svg class="meta-text__icon">
# <use xlink:href="#icon-clock" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="meta-text__text">
# 35 mins
# </span>
# </span>
# </div>
# </a>
# <a class="comp mntl-card-list-items mntl-document-card mntl-card card" data-cta="" data-doc-id="7099338" data-ordinal="8" data-tax-levels="" href="https://www.simplyrecipes.com/potato-kugel-recipe-7099338" id="mntl-card-list-items_2-0-7">
# <div class="card__media" data-tag="Side Dishes">
# <div class="img-placeholder" style="padding-bottom:75.0%;">
# <img alt="Potato Kugel in a Casserole Dish Surrounded by a Small Saucer with Herbs, Another Small Saucer with Cracked Pepper, and a Kitchen Linen" class="lazyload card__img" data-dim-ratio="1.5" data-src="https://www.simplyrecipes.com/thmb/x_jVNzSaVso3i17y9w8XOwP6HbY=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Passover-Potato-Kugel-LEAD-01-e883eff6daf348d39a65f94919e8298c.jpg" height="225" width="300"/>
# <noscript>
# <img alt="Potato Kugel in a Casserole Dish Surrounded by a Small Saucer with Herbs, Another Small Saucer with Cracked Pepper, and a Kitchen Linen" class="img--noscript card__img" height="225" src="https://www.simplyrecipes.com/thmb/x_jVNzSaVso3i17y9w8XOwP6HbY=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Passover-Potato-Kugel-LEAD-01-e883eff6daf348d39a65f94919e8298c.jpg" width="300"/>
# </noscript>
# </div> </div>
# <div class="card__content" data-tag="Side Dishes">
# <div class="card__header"></div>
# <span class="card__title"><span class="card__title-text">Potato Kugel</span></span>
# </div>
# <div class="loc card__footer">
# <span class="comp meta-text--recipe meta-text" id="meta-text--recipe_4-0-7">
# <svg class="meta-text__icon">
# <use xlink:href="#icon-clock" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="meta-text__text">
# 90 mins
# </span>
# </span>
# </div>
# </a>
# <a class="comp mntl-card-list-items mntl-document-card mntl-card card" data-cta="" data-doc-id="7098119" data-ordinal="9" data-tax-levels="" href="https://www.simplyrecipes.com/3-ingredient-banana-pancakes-recipe-7098119" id="mntl-card-list-items_2-0-8">
# <div class="card__media" data-tag="Breakfast">
# <div class="img-placeholder" style="padding-bottom:75.0%;">
# <img alt="Plate with a Stack of 3-Ingredient Banana Pancakes with Butter, Surrounded by a Plate with More Pancakes, Cups of of Coffee, and Utensils on a Table Napkin" class="lazyload card__img" data-dim-ratio="1.5" data-src="https://www.simplyrecipes.com/thmb/BgiOxhgFQGh2AccfZG3HmqSTbgY=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-3-Ingredients-Banana-Pancake-LEAD-06-881d05632ab647e2990d5ff091159848.jpg" height="225" width="300"/>
# <noscript>
# <img alt="Plate with a Stack of 3-Ingredient Banana Pancakes with Butter, Surrounded by a Plate with More Pancakes, Cups of of Coffee, and Utensils on a Table Napkin" class="img--noscript card__img" height="225" src="https://www.simplyrecipes.com/thmb/BgiOxhgFQGh2AccfZG3HmqSTbgY=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-3-Ingredients-Banana-Pancake-LEAD-06-881d05632ab647e2990d5ff091159848.jpg" width="300"/>
# </noscript>
# </div> </div>
# <div class="card__content" data-tag="Breakfast">
# <div class="card__header"></div>
# <span class="card__title"><span class="card__title-text">3-Ingredient Banana Pancakes</span></span>
# </div>
# <div class="loc card__footer">
# <span class="comp meta-text--recipe meta-text" id="meta-text--recipe_4-0-8">
# <svg class="meta-text__icon">
# <use xlink:href="#icon-clock" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="meta-text__text">
# 25 mins
# </span>
# </span>
# <div class="comp aggregate-star-rating aggregate-star-rating--card" id="aggregate-star-rating--card_3-0-4">
# <span class="aggregate-star-rating__title">Ratings</span>
# <div class="comp mntl-aggregate-star-rating mntl-rating" data-doc-id="0" id="mntl-aggregate-star-rating_4-0-4">
# <span aria-label="Rate 1-star" class="active" data-ordinal="1" data-rating="1">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 2-star" class="active" data-ordinal="2" data-rating="2">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 3-star" class="active" data-ordinal="3" data-rating="3">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 4-star" class="active" data-ordinal="4" data-rating="4">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 5-star" class="active" data-ordinal="5" data-rating="5">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span></div>
# </div>
# </div>
# </a>
# <a class="comp mntl-card-list-items mntl-document-card mntl-card card" data-cta="" data-doc-id="7099898" data-ordinal="10" data-tax-levels="" href="https://www.simplyrecipes.com/microwave-rice-recipe-7099898" id="mntl-card-list-items_2-0-9">
# <div class="card__media" data-tag="Side Dishes">
# <div class="img-placeholder" style="padding-bottom:75.0%;">
# <img alt="Microwave Rice in a Bowl on a Kitchen Towel with a Wooden Spoon " class="lazyload card__img" data-dim-ratio="1.5" data-src="https://www.simplyrecipes.com/thmb/WK7o65_zOlJKYvtasliiacnfRn8=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/SimplyRecipes_MicrowaveRice-LEAD-3-c1b036addf0c4d7d8c18e2e15a48b513.jpg" height="225" width="300"/>
# <noscript>
# <img alt="Microwave Rice in a Bowl on a Kitchen Towel with a Wooden Spoon " class="img--noscript card__img" height="225" src="https://www.simplyrecipes.com/thmb/WK7o65_zOlJKYvtasliiacnfRn8=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/SimplyRecipes_MicrowaveRice-LEAD-3-c1b036addf0c4d7d8c18e2e15a48b513.jpg" width="300"/>
# </noscript>
# </div> </div>
# <div class="card__content" data-tag="Side Dishes">
# <div class="card__header"></div>
# <span class="card__title"><span class="card__title-text">Microwave Rice</span></span>
# </div>
# <div class="loc card__footer">
# <span class="comp meta-text--recipe meta-text" id="meta-text--recipe_4-0-9">
# <svg class="meta-text__icon">
# <use xlink:href="#icon-clock" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="meta-text__text">
# 20 mins
# </span>
# </span>
# </div>
# </a>
# <a class="comp mntl-card-list-items mntl-document-card mntl-card card" data-cta="" data-doc-id="7099909" data-ordinal="11" data-tax-levels="" href="https://www.simplyrecipes.com/microwave-bacon-recipe-fast-and-easy-7099909" id="mntl-card-list-items_2-0-10">
# <div class="card__media" data-tag="Breakfast">
# <div class="img-placeholder" style="padding-bottom:75.0%;">
# <img alt="Plate of Microwave Bacon with Sunny Side Eggs and Slices of Buttered Toast" class="lazyload card__img" data-dim-ratio="1.503" data-src="https://www.simplyrecipes.com/thmb/1_2W3v80i74m1WDfoYGbY0cuRI0=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Microwave-Bacon-LEAD-3-3b6c20139db04ac7a10409e10865aa1a.jpg" height="225" width="300"/>
# <noscript>
# <img alt="Plate of Microwave Bacon with Sunny Side Eggs and Slices of Buttered Toast" class="img--noscript card__img" height="225" src="https://www.simplyrecipes.com/thmb/1_2W3v80i74m1WDfoYGbY0cuRI0=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Microwave-Bacon-LEAD-3-3b6c20139db04ac7a10409e10865aa1a.jpg" width="300"/>
# </noscript>
# </div> </div>
# <div class="card__content" data-tag="Breakfast">
# <div class="card__header"></div>
# <span class="card__title"><span class="card__title-text">Microwave Bacon</span></span>
# </div>
# <div class="loc card__footer">
# <span class="comp meta-text--recipe meta-text" id="meta-text--recipe_4-0-10">
# <svg class="meta-text__icon">
# <use xlink:href="#icon-clock" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="meta-text__text">
# 6 mins
# </span>
# </span>
# </div>
# </a>
# <a class="comp mntl-card-list-items mntl-document-card mntl-card card" data-cta="" data-doc-id="7099268" data-ordinal="12" data-tax-levels="" href="https://www.simplyrecipes.com/creamy-white-bean-soup-with-sage-gremolata-recipe-7099268" id="mntl-card-list-items_2-0-11">
# <div class="card__media" data-tag="Dinners">
# <div class="img-placeholder" style="padding-bottom:75.0%;">
# <img alt="Two Bowls of Creamy White Bean Soup with Sage Gremolata, Surrounded by Slices of Bread on the Counter, a Bowl of Sage Gremolata, and Spoons on a Kitchen Towel" class="lazyload card__img" data-dim-ratio="1.5" data-src="https://www.simplyrecipes.com/thmb/tvjp3fAQVHVPADhcinACKX_scac=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Creamy-White-Bean-Soup-LEAD-14-1d6848d3d74f4226b6fe0878474290e1.jpg" height="225" width="300"/>
# <noscript>
# <img alt="Two Bowls of Creamy White Bean Soup with Sage Gremolata, Surrounded by Slices of Bread on the Counter, a Bowl of Sage Gremolata, and Spoons on a Kitchen Towel" class="img--noscript card__img" height="225" src="https://www.simplyrecipes.com/thmb/tvjp3fAQVHVPADhcinACKX_scac=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Creamy-White-Bean-Soup-LEAD-14-1d6848d3d74f4226b6fe0878474290e1.jpg" width="300"/>
# </noscript>
# </div> </div>
# <div class="card__content" data-tag="Dinners">
# <div class="card__header"></div>
# <span class="card__title"><span class="card__title-text">Creamy White Bean Soup with Sage Gremolata </span></span>
# </div>
# <div class="loc card__footer">
# <span class="comp meta-text--recipe meta-text" id="meta-text--recipe_4-0-11">
# <svg class="meta-text__icon">
# <use xlink:href="#icon-clock" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="meta-text__text">
# 60 mins
# </span>
# </span>
# <div class="comp aggregate-star-rating aggregate-star-rating--card" id="aggregate-star-rating--card_3-0-5">
# <span class="aggregate-star-rating__title">Ratings</span>
# <div class="comp mntl-aggregate-star-rating mntl-rating" data-doc-id="0" id="mntl-aggregate-star-rating_4-0-5">
# <span aria-label="Rate 1-star" class="active" data-ordinal="1" data-rating="1">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 2-star" class="active" data-ordinal="2" data-rating="2">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 3-star" class="active" data-ordinal="3" data-rating="3">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 4-star" class="active" data-ordinal="4" data-rating="4">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# ...
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 5-star" class="active" data-ordinal="5" data-rating="5">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span></div>
# </div>
# </div>
# </a>
# <a class="comp mntl-card-list-items mntl-document-card mntl-card card" data-cta="" data-doc-id="6828209" data-ordinal="56" data-tax-levels="" href="https://www.simplyrecipes.com/creamy-chicken-enchilada-soup-recipe-6828209" id="mntl-card-list-items_2-0-55">
# <div class="card__media" data-tag="Dinners">
# <div class="img-placeholder" style="padding-bottom:75.0%;">
# <img alt="Bowl of Creamy Chicken Enchilada Soup Garnished with Cilantro, Crema, and Jalapenos Surrounded by Little Bowls with Toppings (Jalapenos, Lime Wedges, Cotija, and Crema)" class="lazyload card__img" data-dim-ratio="1.5" data-src="https://www.simplyrecipes.com/thmb/g6rKfiVYqpOUG8f8L_IIFur2BeY=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Enchilada-Soup-LEAD-09-896382bd62b540749de64d85b4917649.jpg" height="225" width="300"/>
# <noscript>
# <img alt="Bowl of Creamy Chicken Enchilada Soup Garnished with Cilantro, Crema, and Jalapenos Surrounded by Little Bowls with Toppings (Jalapenos, Lime Wedges, Cotija, and Crema)" class="img--noscript card__img" height="225" src="https://www.simplyrecipes.com/thmb/g6rKfiVYqpOUG8f8L_IIFur2BeY=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Enchilada-Soup-LEAD-09-896382bd62b540749de64d85b4917649.jpg" width="300"/>
# </noscript>
# </div> </div>
# <div class="card__content" data-tag="Dinners">
# <div class="card__header"></div>
# <span class="card__title"><span class="card__title-text">Creamy Chicken Enchilada Soup</span></span>
# </div>
# <div class="loc card__footer">
# <span class="comp meta-text--recipe meta-text" id="meta-text--recipe_4-0-55">
# <svg class="meta-text__icon">
# <use xlink:href="#icon-clock" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="meta-text__text">
# 40 mins
# </span>
# </span>
# <div class="comp aggregate-star-rating aggregate-star-rating--card" id="aggregate-star-rating--card_3-0-22">
# <span class="aggregate-star-rating__title">Ratings</span>
# <div class="comp mntl-aggregate-star-rating mntl-rating" data-doc-id="0" id="mntl-aggregate-star-rating_4-0-22">
# <span aria-label="Rate 1-star" class="active" data-ordinal="1" data-rating="1">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 2-star" class="active" data-ordinal="2" data-rating="2">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 3-star" class="active" data-ordinal="3" data-rating="3">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 4-star" class="active" data-ordinal="4" data-rating="4">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 5-star" class="active" data-ordinal="5" data-rating="5">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span></div>
# </div>
# </div>
# </a>
# <a class="comp mntl-card-list-items mntl-document-card mntl-card card" data-cta="" data-doc-id="6835896" data-ordinal="57" data-tax-levels="" href="https://www.simplyrecipes.com/heart-shaped-pepperoni-pizza-recipe-6835896" id="mntl-card-list-items_2-0-56">
# <div class="card__media" data-tag="Dinners">
# <div class="img-placeholder" style="padding-bottom:75.0%;">
# <img alt="Heart-Shaped Pepperoni Pizza on a Pizza Peel Next a Stack of Plate " class="lazyload card__img" data-dim-ratio="1.5" data-src="https://www.simplyrecipes.com/thmb/BaeVk2-De4btZ-_sbYi5hl01htA=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Heart-Shaped-Pizza-LEAD-04-4a84c89f9d8d4fa692d04e58c22e5cd0.jpg" height="225" width="300"/>
# <noscript>
# <img alt="Heart-Shaped Pepperoni Pizza on a Pizza Peel Next a Stack of Plate " class="img--noscript card__img" height="225" src="https://www.simplyrecipes.com/thmb/BaeVk2-De4btZ-_sbYi5hl01htA=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Heart-Shaped-Pizza-LEAD-04-4a84c89f9d8d4fa692d04e58c22e5cd0.jpg" width="300"/>
# </noscript>
# </div> </div>
# <div class="card__content" data-tag="Dinners">
# <div class="card__header"></div>
# <span class="card__title"><span class="card__title-text">Heart-Shaped Pepperoni Pizza </span></span>
# </div>
# <div class="loc card__footer">
# <span class="comp meta-text--recipe meta-text" id="meta-text--recipe_4-0-56">
# <svg class="meta-text__icon">
# <use xlink:href="#icon-clock" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="meta-text__text">
# 25 mins
# </span>
# </span>
# </div>
# </a>
# <a class="comp mntl-card-list-items mntl-document-card mntl-card card" data-cta="" data-doc-id="6835442" data-ordinal="58" data-tax-levels="" href="https://www.simplyrecipes.com/sweet-and-sour-cabbage-soup-recipe-6835442" id="mntl-card-list-items_2-0-57">
# <div class="card__media" data-tag="Dinners">
# <div class="img-placeholder" style="padding-bottom:75.0%;">
# <img alt="Sweet and Sour Cabbage Soup in a Large Pot with Some Raised Up Using a Wooden Spoon, and Surrounding the Pot, a Kitchen Linen and a Stack of Bowls with Utensils" class="lazyload card__img" data-dim-ratio="1.5" data-src="https://www.simplyrecipes.com/thmb/QStYIBRiBHbko90ky4JzIUXfUV4=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Sweet-Sour-Cabbage-LEAD-01-69cfc6504cc24de2a79a1ce7af36ee95.jpg" height="225" width="300"/>
# <noscript>
# <img alt="Sweet and Sour Cabbage Soup in a Large Pot with Some Raised Up Using a Wooden Spoon, and Surrounding the Pot, a Kitchen Linen and a Stack of Bowls with Utensils" class="img--noscript card__img" height="225" src="https://www.simplyrecipes.com/thmb/QStYIBRiBHbko90ky4JzIUXfUV4=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Sweet-Sour-Cabbage-LEAD-01-69cfc6504cc24de2a79a1ce7af36ee95.jpg" width="300"/>
# </noscript>
# </div> </div>
# <div class="card__content" data-tag="Dinners">
# <div class="card__header"></div>
# <span class="card__title"><span class="card__title-text">Sweet and Sour Cabbage Soup</span></span>
# </div>
# <div class="loc card__footer">
# <span class="comp meta-text--recipe meta-text" id="meta-text--recipe_4-0-57">
# <svg class="meta-text__icon">
# <use xlink:href="#icon-clock" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="meta-text__text">
# 50 mins
# </span>
# </span>
# </div>
# </a>
# <a class="comp mntl-card-list-items mntl-document-card mntl-card card" data-cta="" data-doc-id="6835713" data-ordinal="59" data-tax-levels="" href="https://www.simplyrecipes.com/cheeseburger-casserole-recipe-6835713" id="mntl-card-list-items_2-0-58">
# <div class="card__media" data-tag="Dinners">
# <div class="img-placeholder" style="padding-bottom:75.0%;">
# <img alt="Casserole Dish of Cheeseburger Casserole with a Serving Already Served Using a Spoon at a Table Setting (a Plate with a Serving of Casserole, Bowl of Dry Parsley, a Table Napkin, and a Glass of Ice Water)" class="lazyload card__img" data-dim-ratio="1.498" data-src="https://www.simplyrecipes.com/thmb/IOhIG9iDzASo7PmS2wPpp2n6UPw=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Cheeseburger-Casserole-Lead-8-25afc1e6bb5f40df9b597e9d7b1f9507.jpg" height="225" width="300"/>
# <noscript>
# <img alt="Casserole Dish of Cheeseburger Casserole with a Serving Already Served Using a Spoon at a Table Setting (a Plate with a Serving of Casserole, Bowl of Dry Parsley, a Table Napkin, and a Glass of Ice Water)" class="img--noscript card__img" height="225" src="https://www.simplyrecipes.com/thmb/IOhIG9iDzASo7PmS2wPpp2n6UPw=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Cheeseburger-Casserole-Lead-8-25afc1e6bb5f40df9b597e9d7b1f9507.jpg" width="300"/>
# </noscript>
# </div> </div>
# <div class="card__content" data-tag="Dinners">
# <div class="card__header"></div>
# <span class="card__title"><span class="card__title-text">Cheeseburger Casserole</span></span>
# </div>
# <div class="loc card__footer">
# <span class="comp meta-text--recipe meta-text" id="meta-text--recipe_4-0-58">
# <svg class="meta-text__icon">
# <use xlink:href="#icon-clock" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="meta-text__text">
# 45 mins
# </span>
# </span>
# <div class="comp aggregate-star-rating aggregate-star-rating--card" id="aggregate-star-rating--card_3-0-23">
# <span class="aggregate-star-rating__title">Ratings</span>
# <div class="comp mntl-aggregate-star-rating mntl-rating" data-doc-id="0" id="mntl-aggregate-star-rating_4-0-23">
# <span aria-label="Rate 1-star" class="active" data-ordinal="1" data-rating="1">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 2-star" class="active" data-ordinal="2" data-rating="2">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 3-star" class="active" data-ordinal="3" data-rating="3">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 4-star" class="active" data-ordinal="4" data-rating="4">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span aria-label="Rate 5-star" class="half" data-ordinal="5" data-rating="5">
# <svg class="star-icon star-icon--inactive">
# <use xlink:href="#aggregate-star-rating__icon--inactive" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--active">
# <use xlink:href="#aggregate-star-rating__icon--active" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <svg class="star-icon star-icon--half">
# <use xlink:href="#aggregate-star-rating__icon--half" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span></div>
# </div>
# </div>
# </a>
# <a class="comp mntl-card-list-items mntl-document-card mntl-card card" data-cta="" data-doc-id="6835783" data-ordinal="60" data-tax-levels="" href="https://www.simplyrecipes.com/cheeseburger-pizza-recipe-6835783" id="mntl-card-list-items_2-0-59">
# <div class="card__media" data-tag="Dinners">
# <div class="img-placeholder" style="padding-bottom:75.0%;">
# <img alt="Slice of Cheeseburger Pizza on Small Plate Next to a Circular Wooden Tray with More Pizza and a Pizza Wheel and on the Counter, a Kitchen Towel" class="lazyload card__img" data-dim-ratio="1.498" data-src="https://www.simplyrecipes.com/thmb/8ewLSWb0k31IPGn7K58aaCNuJt4=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Cheeseburger-Pizza-LEAD-9-1c314d9afb874d75a6db28e25e59614a.jpg" height="225" width="300"/>
# <noscript>
# <img alt="Slice of Cheeseburger Pizza on Small Plate Next to a Circular Wooden Tray with More Pizza and a Pizza Wheel and on the Counter, a Kitchen Towel" class="img--noscript card__img" height="225" src="https://www.simplyrecipes.com/thmb/8ewLSWb0k31IPGn7K58aaCNuJt4=/300x225/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Cheeseburger-Pizza-LEAD-9-1c314d9afb874d75a6db28e25e59614a.jpg" width="300"/>
# </noscript>
# </div> </div>
# <div class="card__content" data-tag="Dinners">
# <div class="card__header"></div>
# <span class="card__title"><span class="card__title-text">Cheeseburger Pizza </span></span>
# </div>
# <div class="loc card__footer">
# <span class="comp meta-text--recipe meta-text" id="meta-text--recipe_4-0-59">
# <svg class="meta-text__icon">
# <use xlink:href="#icon-clock" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="meta-text__text">
# 45 mins
# </span>
# </span>
# </div>
# </a>
# <div class="comp mntl-card-list__bottom mntl-block" id="mntl-card-list__bottom_1-0"></div>
# </div>
# </div>
# </div>

# %%
get_images(data)
# Out:
# ['Simply-Recipes-Vegan-MeatballsLEAD-12-55c5f73e734d47ea8233e6370031b517.jpg',
#  'Simply-Recipes-Pesto-Chicken-Meatballs-LEAD-26-e8bcc6962b3d42549ab05750c44f0ab0.jpg',
#  'Simply-Recipes-Extra-Rich-Chocolate-Frosting-METHOD-3-version-2-64e1448e7b744cb4a732732b6ba8ecbf.jpg',
#  'Simply-Recipes-Lok-Lak-Mustard-LEAD-06-4b5fba1a87b64b4cad472b261375c272.jpg',
#  'Simply-Recipes-Oatmeal-Banana-Cookies-LEAD-05-a0047f8e7c2a484c8529ba49db9f90d9.jpg',
#  'Simply-Recipes-Chicken-Adobo-Meatballs-LEAD-05-543f271321c142fe84a3acb17ab5dd3c.jpg',
#  'Simple-Recipes-Egg-Masala-Curry-Lead-06-1225dad91b8b4531bdc0195fea8fa774.jpg',
#  'Simply-Recipes-Lions-Head-Meatball-LEAD-02-a4f2a9955428409097f0155e98df2b9c.jpg',
#  'Simply-Recipes-Beef-Enchilada-Casserole-LEAD-02-ad4ba62363a44a85b8f281a806697f44.jpg',
#  'Simply-Recipes-Oyster-PoBoy-LEAD-03-919049a1cacb4b78881ced4ea2eac4a7.jpg',
#  'Passover-Potato-Kugel-LEAD-01-e883eff6daf348d39a65f94919e8298c.jpg',
#  'Simply-Recipes-3-Ingredients-Banana-Pancake-LEAD-06-881d05632ab647e2990d5ff091159848.jpg',
#  'SimplyRecipes_MicrowaveRice-LEAD-3-c1b036addf0c4d7d8c18e2e15a48b513.jpg',
#  'Simply-Recipes-Microwave-Bacon-LEAD-3-3b6c20139db04ac7a10409e10865aa1a.jpg',
#  'Simply-Recipes-Creamy-White-Bean-Soup-LEAD-14-1d6848d3d74f4226b6fe0878474290e1.jpg',
#  'SimplyRecipes_BlueberryMuffinTops-LEAD-6-207bd1750f304b8a97677e9efb1e45fd.jpg',
#  'Simply-Recipes-Pancit-Bihon-Bowls-LEAD-07-06bb454291ca49088efeca4a9b232ebd.jpg',
#  'Simply-Recipes-Snickers-Dates-METHOD-04-568256d5d86b42b79377555bdb48e5db.jpg',
#  'SERP1-Simply-Recipes-Chicken-Enchilada-Casserole-METHOD-07-cc18985ca1e445df8662f9d053740aaf.jpg',
#  'Simply-Recipes-Microwave-Sweet-Potato-LEAD-1-5d8be9e95deb4c348eb5d627f57e21b2.jpg',
#  'Simply-Recipes_Sheetpan-Pancakes_LEAD_1-35bc4ba55c1645c28de43199115d9f2a.jpg',
#  'Simply-Recipes-Brasied-BBQ-Ribs-LEAD-02-11223a61bfbc432e8aa7581732caf99d.jpg',
#  'Simply-Recipes-Shrimp-Chorizo-Chowder-LEAD-01-22e141178aba43baade0da7c7cbee88f.jpg',
#  'Simply-Recipes-Garam-Masala-Fish-Sticks-LEAD-5-e87828b2b71d4e9cb94ce56f336923f8.jpg',
#  'Simply-Recipes-Roasted-Sweet-Potato-Salad-SEO-5151d0274e5041029c8875bceb386db5.jpg',
#  'Simply-Recipes-Chocolate-Mayonnaise-Sheet-Cake-Lead-09-d152d3de4179450388265d2fb0b19ffb.jpg',
#  'Simply-Recipes-Patty-Melt-LEAD-4copy2-0b1c45d2295746d7bf105e0193a93d1e.jpg',
#  'Simply-Recipes-Seafood-Congee-LEAD-08-4ee24c792d5d4e2bbebc8fffa58e14be.jpg',
#  'Simply-Recipes-Vegan-Chicken-Nuggets-LEAD-2-e0348411168648e0ad0c1f1c9944a294.jpg',
#  'Simply-Recipes-Black-Bean-Smash-Burgers-LEAD-3-17423095c32e4b6596cd324790c88584.jpg',
#  'Simply-Recipes-Copycat-Sofritas-LEAD-02-cb89cd8131154d5db9b8e93b75839e6f.jpg',
#  'Simply-Recipes-Vegan-Nachos-LEAD-SERP-3b17bcef4dd248ba8a315f054dd47757.jpg',
#  'Simply-Recipes-Banoffee-Pie-LEAD-03-f508bdde2cb34aca9fdb7a392328dfb2.jpg',
#  'Simply-Recipes-French-Press-Coffee-METHOD-07-e61f9c9136b94f3389522ec2f52892a5.jpg',
#  'Simply-Recipes-Buffalo-Hummos-LEAD-02-cad24e1be6324a6f8d0c67cf5143e067.jpg',
#  'Simply-Recipes-Bibimbap-LEAD-03-b1a2a13722d04bdfaddcb1030d94ef58.jpg',
#  'Simply-Recipes-Vegan-Mac-and-Cheese-LEAD-5-abbd3b35ed9e430cad1c02b949b6619a.jpg',
#  'Simply-Recipes-Sourdough-Sandwich-Loaf-LEAD-05-7fef5b3baaee4f21b24ff9c369c22133.jpg',
#  'Simply-Recipes-Smashed-Potatoes-LEAD-02-57e7647320a247028409f17326c95b47.jpg',
#  'Simply-Recipes-Spatzel-LEAD-04-e7955fbc59f942b8acee04e610328a47.jpg',
#  'Simply-Recipes-Gruyere-Pizza-LEAD-03-34a4d385e99b4492bc1a68b92f176b97.jpg',
#  'Simply-Recipes-Brioche-Loaf-LEAD-07-4546510d3d1c4b53bd2aef9f15228026.jpg',
#  'Simply-Recipes-Corn-Crabmeat-Chowder-LEAD-2-1efaa9372db8431193cd70cbf1a2a429.jpg',
#  'Simply-Recipes-Microwave-Steamed-Broccoli-LEAD-04-3068b438137f49b499886d4a6327a022.jpg',
#  'Simply-Recipes-Simple-Chicken-Congee-LEAD-03-4b2e0b096f9946849b096aeb0b2443d4.jpg',
#  'Simply-Recipes-English-Muffin-Bread-LEAD-01-6324b38b51be405b8d84e39159d6fe6e.jpg',
#  'Simply-Recipes-Microwaved-Baked-Potato-LEAD-01-734e3c50471442598f791c8afe95617f.jpg',
#  'VeggieBurgersPlated20221127-4Z9A6582-2-ce1c47195a6847e48f9305e853f8067f.jpg',
#  'Simply-Recipes-Red-Bean-Tangyuan-LEAD-04-48002af57de2423896013a67c3d0901a.jpg',
#  'Simply-Fermented-Elderberry-Syrup-LEAD-02-d60a7af4b57344af8e7a2abbc79137cb.jpg',
#  'Simply-Recipes-Vegan-Cacio-Pepe-LEAD-01-3f2115f87f694d3fa455e33f3cb7d73f.jpg',
#  'Simply-Recipes-Burger-On-Stovetop-LEAD-02-f2735a5ada4e43cfb361dc0cfad246d3.jpg',
#  'Simply-Recipes-Chicken-Lasagna-LEAD-06-088849b6d22a4cdaa9db572072b6f4b3.jpg',
#  'Simply-Recipes-Egg-Foo-Young-LEAD-03-216cfd87dc784584a02c9431cdf06d74.jpg',
#  'Simply-Recipes-Potato-Croquettes-Plates-LEAD-Overhead-Horizontal-68a024c8638f4bab83771c06b26bbdfa.jpg',
#  'Simply-Recipes_Donuts_LEAD_3-051c0a53230b42678386029c72717a33.jpg',
#  'Simply-Recipes-Shrimp-Butter-LEAD-5-2-23f39086c2a9410d8ce02b9b0113e47a.jpg',
#  'Simply-Recipes-Mulling-Spices-LEAD-3-60a9dc63a9144cb49acb66b1844a52b5.jpg',
#  'Simply-Recipes-Enchilada-Soup-LEAD-09-896382bd62b540749de64d85b4917649.jpg',
#  'Simply-Recipes-Heart-Shaped-Pizza-LEAD-04-4a84c89f9d8d4fa692d04e58c22e5cd0.jpg',
#  'Simply-Recipes-Sweet-Sour-Cabbage-LEAD-01-69cfc6504cc24de2a79a1ce7af36ee95.jpg',
#  'Simply-Recipes-Cheeseburger-Casserole-Lead-8-25afc1e6bb5f40df9b597e9d7b1f9507.jpg',
#  'Simply-Recipes-Cheeseburger-Pizza-LEAD-9-1c314d9afb874d75a6db28e25e59614a.jpg']
